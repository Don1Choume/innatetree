# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys
from pathlib import Path

src_dir = Path().resolve().parent/'src'
sys.path.append(str(src_dir))

import numpy as np
from matplotlib import pyplot as plt

# %%
from data import DiscreteLorenz
from visualization import plot_Lorenz

# %%
lorenz_gen = DiscreteLorenz(dt = 0.01)

# %%
# series = lorenz_gen.get_series(1000, (0.02, 0.01, 0.03))
series = lorenz_gen.get_series(int(1e3), (-1, 0, 1))

# %%
plot_Lorenz([series], labels=['main'])

# %%
add_noise_step = [(2e2, np.random.rand(3))]

# %%
series_n1 = lorenz_gen.get_series(int(1e3), (-1, 0, 1),
                                  add_noise_step=add_noise_step)

# %%
plot_Lorenz([series, series_n1], labels=['main', 'n1'])

# %%
from metrics import DTW_distance

# %%
DTW_distance(series, series_n1)
# Out:
# 8988.753620961636

# %%
np.linalg.norm((series-series_n1), ord=2)
# Out:
# 475.2563058575189
