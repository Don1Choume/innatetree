# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys
from pathlib import Path

src_dir = Path().resolve().parent/'src'
sys.path.append(str(src_dir))

import numpy as np
from matplotlib import pyplot as plt

# %%
from metrics import DTW_distance

# %%
t = np.arange(1000)
x1 = np.sin(t/10)
x2 = np.sin(t/10+1)
x3 = np.sin(t/10.1)
plt.plot(t, x1)
plt.plot(t, x2)
plt.plot(t, x3)

# %%
DTW_distance(x1, x1, 0)
# Out:
# 0.0

# %%
DTW_distance(x1, x2, 0)
# Out:
# 9.021625968208728

# %%
DTW_distance(x1, x3, 0)
# Out:
# 17.49860242924445

# %%
DTW_distance(x1, np.zeros_like(x1), 0)
# Out:
# 638.3573184795978

# %%
np.linalg.norm((x1-x1), ord=2)
# Out:
# 0.0

# %%
np.linalg.norm((x1-x2), ord=2)
# Out:
# 21.389788082818484

# %%
np.linalg.norm((x1-x3), ord=2)
# Out:
# 12.386450181795514

# %%
np.linalg.norm((x1), ord=2)
# Out:
# 22.40642224515179
