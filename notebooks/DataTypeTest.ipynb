# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys
from pathlib import Path

src_dir = Path().resolve().parent/'src'
sys.path.append(str(src_dir))

import numpy as np
from matplotlib import pyplot as plt

# %%
from data import MatlabGen, TimingGen, HandWritingGen

# %%
# data_gen1 = MatlabGen()
data_gen1 = MatlabGen('hand')

inputs1 = data_gen1.gen_input()
outputs1 = data_gen1.gen_output()

# %%
plt.plot(inputs1)
# Out:
# [<matplotlib.lines.Line2D at 0x2480e31ccc0>,
#  <matplotlib.lines.Line2D at 0x2480e31ce10>]

# %%
plt.plot(outputs1)
# Out:
# [<matplotlib.lines.Line2D at 0x2480e3f8128>,
#  <matplotlib.lines.Line2D at 0x2480e3f8278>]

# %%
# data_gen2 = TimingGen()
data_gen2 = HandWritingGen()

inputs2 = data_gen2.gen_input()
outputs2 = data_gen2.gen_output()

# %%
plt.plot(inputs2)
# Out:
# [<matplotlib.lines.Line2D at 0x2480f4fb7b8>,
#  <matplotlib.lines.Line2D at 0x2480f4fb908>]

# %%
plt.plot(outputs2)
# Out:
# [<matplotlib.lines.Line2D at 0x2480f55ed68>,
#  <matplotlib.lines.Line2D at 0x2480f55eeb8>]

# %%
data_gen2.gen_train_window().shape
# Out:
# (5144,)
